# %% [markdown]
# Set up game (no learners yet)

# %%
#%run swarm_game.py
# %run notebook_game_helper.py
#animate_game(test_game, 10)

# %% [markdown]
# Set up neural network visualization

# %%
# %run ff_nn.py
# Out:
# Neural network 'net' ready for training

# %%
net.fit(X, y, .000000001, 5000, animate=True)
# Out:
# None
# Error:0.0150439277398

# %%
net.fit(X, y, 0.1, 60000, animate=True)
# Out:
# None
# Error:0.228292085313
