# %%
from reinforcement_training import *
from notebook_game_helper import *
# Out:
# Using Theano backend.

# %%
model0, log = main(training_game_size = 8, training_episodes = 100, steps = 10)
# Out:
# Episode 99, Wins: 14, Replay Loss: 9.11142: 100%|██████████| 100/100 [00:20<00:00,  5.85it/s]

# %%
val_game = NeuralNaviGame(8, 8, model = model0)

# %%
val_game.setup()

# %%
animate_game(val_game, n = 10)
# Out:
# None

# %%
val_game.shift_goal()

# %%
pl.plot(np.log(log[1]))
pl.title("RL Loss, 100 eps w/ 50 steps, Look: 20")
pl.savefig("notes/rl_curve_x.png")
pl.show()
