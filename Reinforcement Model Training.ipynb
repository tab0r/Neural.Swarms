# %%
from reinforcement_training import *
from notebook_game_helper import *

# %%
model0, log = main(training_game_size = 8, training_episodes = 1000, steps = 10)
# Out:
# Network training starting:   0%|          | 0/1000 [00:00<?, ?it/s]
#
#
#
#
# Episode 0, Wins: 0, Replay Loss: 11.5173:   0%|          | 0/1000 [00:01<?, ?it/s]
#
#
# Episode 0, Wins: 0, Replay Loss: 11.5173:   0%|          | 1/1000 [00:01<19:57,  1.20s/it]
#
#
# Episode 1, Wins: 0, Replay Loss: 11.4506:   0%|          | 1/1000 [00:01<22:49,  1.37s/it]
#
#
# Episode 1, Wins: 0, Replay Loss: 11.4506:   0%|          | 2/1000 [00:01<14:49,  1.12it/s]
#
#
# Episode 2, Wins: 0, Replay Loss: 11.3779:   0%|          | 2/1000 [00:01<13:01,  1.28it/s]
#
#
# Episode 2, Wins: 0, Replay Loss: 11.3779:   0%|          | 3/1000 [00:01<11:20,  1.47it/s]
#
#
# Episode 3, Wins: 0, Replay Loss: 11.26:   0%|          | 3/1000 [00:01<09:35,  1.73it/s]
#
#
# Episode 3, Wins: 0, Replay Loss: 11.26:   0%|          | 4/1000 [00:01<08:45,  1.90it/s]
#
#
# Episode 4, Wins: 0, Replay Loss: 11.2297:   0%|          | 4/1000 [00:01<08:02,  2.07it/s]
#
#
# Episode 4, Wins: 0, Replay Loss: 11.2297:   0%|          | 5/1000 [00:01<07:08,  2.32it/s]
#
#
# Episode 5, Wins: 1, Replay Loss: 11.2845:   0%|          | 5/1000 [00:02<07:02,  2.36it/s]
#
#
# Episode 5, Wins: 1, Replay Loss: 11.2845:   1%|          | 6/1000 [00:02<05:54,  2.81it/s]
#
#
# Episode 6, Wins: 1, Replay Loss: 11.2241:   1%|          | 6/1000 [00:02<06:26,  2.57it/s]
#
#
# Episode 6, Wins: 1, Replay Loss: 11.2241:   1%|          | 7/1000 [00:02<05:11,  3.19it/s]
#
#
# Episode 7, Wins: 1, Replay Loss: 11.1029:   1%|          | 7/1000 [00:02<06:00,  2.75it/s]
#
#
# Episode 7, Wins: 1, Replay Loss: 11.1029:   1%|          | 8/1000 [00:02<04:39,  3.54it/s]
#
#
# Episode 8, Wins: 1, Replay Loss: 11.9358:   1%|          | 8/1000 [00:02<05:38,  2.93it/s]
#
#
# Episode 8, Wins: 1, Replay Loss: 11.9358:   1%|          | 9/1000 [00:02<04:10,  3.96it/s]
#
#
# Episode 9, Wins: 1, Replay Loss: 11.1611:   1%|          | 9/1000 [00:02<05:20,  3.09it/s]
#
#
# Episode 9, Wins: 1, Replay Loss: 11.1611:   1%|          | 10/1000 [00:02<03:49,  4.31it/s]
#
#
# Episode 10, Wins: 1, Replay Loss: 11.9053:   1%|          | 10/1000 [00:03<05:06,  3.23it/s]
#
#
# Episode 10, Wins: 1, Replay Loss: 11.9053:   1%|          | 11/1000 [00:03<03:34,  4.62it/s]
#
#
# Episode 11, Wins: 1, Replay Loss: 11.7459:   1%|          | 11/1000 [00:03<04:55,  3.35it/s]
#
#
# Episode 11, Wins: 1, Replay Loss: 11.7459:   1%|          | 12/1000 [00:03<03:27,  4.76it/s]
#
#
# Episode 12, Wins: 1, Replay Loss: 52.8951:   1%|          | 12/1000 [00:03<04:47,  3.43it/s]
#
#
# Episode 12, Wins: 1, Replay Loss: 52.8951:   1%|▏         | 13/1000 [00:03<03:27,  4.76it/s]
#
#
# Episode 13, Wins: 1, Replay Loss: 11.7269:   1%|▏         | 13/1000 [00:03<04:40,  3.52it/s]
#
#
# Episode 13, Wins: 1, Replay Loss: 11.7269:   1%|▏         | 14/1000 [00:03<03:23,  4.86it/s]
#
#
# Episode 14, Wins: 1, Replay Loss: 10.9505:   1%|▏         | 14/1000 [00:03<04:33,  3.61it/s]
#
#
# Episode 14, Wins: 1, Replay Loss: 10.9505:   2%|▏         | 15/1000 [00:03<03:17,  4.98it/s]
#
#
# Episode 15, Wins: 1, Replay Loss: 10.6258:   2%|▏         | 15/1000 [00:04<04:26,  3.69it/s]
#
#
# Episode 15, Wins: 1, Replay Loss: 10.6258:   2%|▏         | 16/1000 [00:04<03:12,  5.11it/s]
#
#
# Episode 16, Wins: 2, Replay Loss: 11.7635:   2%|▏         | 16/1000 [00:04<04:22,  3.75it/s]
#
#
# Episode 16, Wins: 2, Replay Loss: 11.7635:   2%|▏         | 17/1000 [00:04<03:12,  5.10it/s]
#
#
# Episode 17, Wins: 2, Replay Loss: 10.7879:   2%|▏         | 17/1000 [00:04<04:17,  3.81it/s]
#
#
# Episode 17, Wins: 2, Replay Loss: 10.7879:   2%|▏         | 18/1000 [00:04<03:12,  5.11it/s]
#
#
# Episode 18, Wins: 2, Replay Loss: 11.5894:   2%|▏         | 18/1000 [00:04<04:12,  3.90it/s]
#
#
# Episode 18, Wins: 2, Replay Loss: 11.5894:   2%|▏         | 19/1000 [00:04<03:02,  5.37it/s]
#
#
# Episode 19, Wins: 2, Replay Loss: 10.8114:   2%|▏         | 19/1000 [00:04<04:09,  3.93it/s]
#
#
# Episode 19, Wins: 2, Replay Loss: 10.8114:   2%|▏         | 20/1000 [00:04<03:09,  5.17it/s]
#
#
# Episode 20, Wins: 2, Replay Loss: 10.6531:   2%|▏         | 20/1000 [00:05<04:06,  3.98it/s]
#
#
# Episode 20, Wins: 2, Replay Loss: 10.6531:   2%|▏         | 21/1000 [00:05<03:10,  5.14it/s]
#
#
# Episode 21, Wins: 2, Replay Loss: 11.0461:   2%|▏         | 21/1000 [00:05<04:03,  4.02it/s]
#
#
# Episode 21, Wins: 2, Replay Loss: 11.0461:   2%|▏         | 22/1000 [00:05<03:09,  5.15it/s]
#
#
# Episode 22, Wins: 2, Replay Loss: 52.579:   2%|▏         | 22/1000 [00:05<04:01,  4.05it/s]
#
#
# Episode 22, Wins: 2, Replay Loss: 52.579:   2%|▏         | 23/1000 [00:05<03:14,  5.02it/s]
#
#
# Episode 23, Wins: 2, Replay Loss: 10.5072:   2%|▏         | 23/1000 [00:05<03:57,  4.11it/s]
#
#
# Episode 23, Wins: 2, Replay Loss: 10.5072:   2%|▏         | 24/1000 [00:05<03:05,  5.27it/s]
#
#
# Episode 24, Wins: 2, Replay Loss: 10.3008:   2%|▏         | 24/1000 [00:05<03:55,  4.14it/s]
#
#
# Episode 24, Wins: 2, Replay Loss: 10.3008:   2%|▎         | 25/1000 [00:05<03:07,  5.20it/s]
#
#
# Episode 25, Wins: 2, Replay Loss: 11.5343:   2%|▎         | 25/1000 [00:05<03:53,  4.17it/s]
#
#
# Episode 25, Wins: 2, Replay Loss: 11.5343:   3%|▎         | 26/1000 [00:05<03:07,  5.20it/s]
#
#
# Episode 26, Wins: 2, Replay Loss: 10.3971:   3%|▎         | 26/1000 [00:06<03:51,  4.21it/s]
#
#
# Episode 26, Wins: 2, Replay Loss: 10.3971:   3%|▎         | 27/1000 [00:06<03:06,  5.22it/s]
#
#
# Episode 27, Wins: 2, Replay Loss: 10.6925:   3%|▎         | 27/1000 [00:06<03:49,  4.24it/s]
#
#
# Episode 27, Wins: 2, Replay Loss: 10.6925:   3%|▎         | 28/1000 [00:06<03:06,  5.22it/s]
#
#
# Episode 28, Wins: 3, Replay Loss: 10.0157:   3%|▎         | 28/1000 [00:06<03:47,  4.27it/s]
#
#
# Episode 28, Wins: 3, Replay Loss: 10.0157:   3%|▎         | 29/1000 [00:06<03:05,  5.24it/s]
#
#
# Episode 29, Wins: 3, Replay Loss: 10.0477:   3%|▎         | 29/1000 [00:06<03:46,  4.29it/s]
#
#
# Episode 29, Wins: 3, Replay Loss: 10.0477:   3%|▎         | 30/1000 [00:06<03:05,  5.23it/s]
#
#
# Episode 30, Wins: 3, Replay Loss: 10.104:   3%|▎         | 30/1000 [00:06<03:44,  4.32it/s]
#
#
# Episode 30, Wins: 3, Replay Loss: 10.104:   3%|▎         | 31/1000 [00:06<03:06,  5.19it/s]
#
#
# Episode 31, Wins: 3, Replay Loss: 10.2873:   3%|▎         | 31/1000 [00:07<03:43,  4.34it/s]
#
#
# Episode 31, Wins: 3, Replay Loss: 10.2873:   3%|▎         | 32/1000 [00:07<03:06,  5.20it/s]
#
#
# Episode 32, Wins: 3, Replay Loss: 9.85284:   3%|▎         | 32/1000 [00:07<03:41,  4.36it/s]
#
#
# Episode 32, Wins: 3, Replay Loss: 9.85284:   3%|▎         | 33/1000 [00:07<03:06,  5.19it/s]
#
#
# Episode 33, Wins: 3, Replay Loss: 10.4531:   3%|▎         | 33/1000 [00:07<03:40,  4.39it/s]
#
#
# Episode 33, Wins: 3, Replay Loss: 10.4531:   3%|▎         | 34/1000 [00:07<03:05,  5.22it/s]
#
#
# Episode 34, Wins: 3, Replay Loss: 11.1109:   3%|▎         | 34/1000 [00:07<03:39,  4.39it/s]
#
#
# Episode 34, Wins: 3, Replay Loss: 11.1109:   4%|▎         | 35/1000 [00:07<03:12,  5.01it/s]
#
#
# Episode 35, Wins: 3, Replay Loss: 10.3827:   4%|▎         | 35/1000 [00:07<03:38,  4.41it/s]
#
#
# Episode 35, Wins: 3, Replay Loss: 10.3827:   4%|▎         | 36/1000 [00:07<03:10,  5.06it/s]
#
#
# Episode 36, Wins: 3, Replay Loss: 10.358:   4%|▎         | 36/1000 [00:08<03:37,  4.43it/s]
#
#
# Episode 36, Wins: 3, Replay Loss: 10.358:   4%|▎         | 37/1000 [00:08<03:08,  5.12it/s]
#
#
# Episode 37, Wins: 4, Replay Loss: 9.78244:   4%|▎         | 37/1000 [00:08<03:37,  4.43it/s]
#
#
# Episode 37, Wins: 4, Replay Loss: 9.78244:   4%|▍         | 38/1000 [00:08<03:19,  4.83it/s]
#
#
# Episode 38, Wins: 4, Replay Loss: 9.95635:   4%|▍         | 38/1000 [00:08<03:36,  4.44it/s]
#
#
# Episode 38, Wins: 4, Replay Loss: 9.95635:   4%|▍         | 39/1000 [00:08<03:14,  4.94it/s]
#
#
# Episode 39, Wins: 4, Replay Loss: 10.2732:   4%|▍         | 39/1000 [00:08<03:35,  4.47it/s]
# Episode 39, Wins: 4, Replay Loss: 10.2732:   4%|▍         | 40/1000 [00:08<03:07,  5.13it/s]
#
#
# Episode 40, Wins: 7, Replay Loss: 10.6992:   4%|▍         | 40/1000 [00:08<03:34,  4.48it/s]
#
#
# Episode 40, Wins: 7, Replay Loss: 10.6992:   4%|▍         | 41/1000 [00:08<03:07,  5.12it/s]
#
#
# Episode 41, Wins: 8, Replay Loss: 9.9452:   4%|▍         | 41/1000 [00:09<03:34,  4.48it/s]
#
#
# Episode 41, Wins: 8, Replay Loss: 9.9452:   4%|▍         | 42/1000 [00:09<03:16,  4.87it/s]
#
#
# Episode 42, Wins: 8, Replay Loss: 9.53968:   4%|▍         | 42/1000 [00:09<03:35,  4.45it/s]
#
#
# Episode 42, Wins: 8, Replay Loss: 9.53968:   4%|▍         | 43/1000 [00:09<03:40,  4.34it/s]
#
#
# Episode 43, Wins: 8, Replay Loss: 9.52102:   4%|▍         | 43/1000 [00:09<03:34,  4.46it/s]
#
#
# Episode 43, Wins: 8, Replay Loss: 9.52102:   4%|▍         | 44/1000 [00:09<03:29,  4.56it/s]
#
#
# Episode 44, Wins: 8, Replay Loss: 11.1094:   4%|▍         | 44/1000 [00:09<03:34,  4.46it/s]
#
#
# Episode 44, Wins: 8, Replay Loss: 11.1094:   4%|▍         | 45/1000 [00:09<03:30,  4.53it/s]
#
#
# Episode 45, Wins: 8, Replay Loss: 10.1994:   4%|▍         | 45/1000 [00:10<03:34,  4.45it/s]
#
#
# Episode 45, Wins: 8, Replay Loss: 10.1994:   5%|▍         | 46/1000 [00:10<03:39,  4.35it/s]
#
#
# Episode 46, Wins: 8, Replay Loss: 52.0228:   5%|▍         | 46/1000 [00:10<03:33,  4.47it/s]
#
#
# Episode 46, Wins: 8, Replay Loss: 52.0228:   5%|▍         | 47/1000 [00:10<03:24,  4.65it/s]
#
#
# Episode 47, Wins: 8, Replay Loss: 9.6055:   5%|▍         | 47/1000 [00:10<03:32,  4.48it/s]
#
#
# Episode 47, Wins: 8, Replay Loss: 9.6055:   5%|▍         | 48/1000 [00:10<03:23,  4.68it/s]
#
#
# Episode 48, Wins: 8, Replay Loss: 9.60377:   5%|▍         | 48/1000 [00:10<03:32,  4.49it/s]
#
#
# Episode 48, Wins: 8, Replay Loss: 9.60377:   5%|▍         | 49/1000 [00:10<03:15,  4.85it/s]
#
#
# Episode 49, Wins: 8, Replay Loss: 9.74567:   5%|▍         | 49/1000 [00:10<03:31,  4.50it/s]
#
#
# Episode 49, Wins: 8, Replay Loss: 9.74567:   5%|▌         | 50/1000 [00:10<03:15,  4.87it/s]
#
#
# Episode 50, Wins: 8, Replay Loss: 10.9912:   5%|▌         | 50/1000 [00:11<03:30,  4.52it/s]
#
#
# Episode 50, Wins: 8, Replay Loss: 10.9912:   5%|▌         | 51/1000 [00:11<03:06,  5.09it/s]
#
#
# Episode 51, Wins: 8, Replay Loss: 11.1628:   5%|▌         | 51/1000 [00:11<03:29,  4.53it/s]
#
#
# Episode 51, Wins: 8, Replay Loss: 11.1628:   5%|▌         | 52/1000 [00:11<03:00,  5.24it/s]
#
#
# Episode 52, Wins: 8, Replay Loss: 9.54188:   5%|▌         | 52/1000 [00:11<03:30,  4.51it/s]
#
#
# Episode 52, Wins: 8, Replay Loss: 9.54188:   5%|▌         | 53/1000 [00:11<03:24,  4.64it/s]
#
#
# Episode 53, Wins: 8, Replay Loss: 10.6195:   5%|▌         | 53/1000 [00:11<03:29,  4.52it/s]
#
#
# Episode 53, Wins: 8, Replay Loss: 10.6195:   5%|▌         | 54/1000 [00:11<03:22,  4.67it/s]
#
#
# Episode 54, Wins: 8, Replay Loss: 10.0454:   5%|▌         | 54/1000 [00:11<03:28,  4.53it/s]
#
#
# Episode 54, Wins: 8, Replay Loss: 10.0454:   6%|▌         | 55/1000 [00:11<03:16,  4.82it/s]
#
#
# Episode 55, Wins: 8, Replay Loss: 9.4505:   6%|▌         | 55/1000 [00:12<03:28,  4.53it/s]
#
#
# Episode 55, Wins: 8, Replay Loss: 9.4505:   6%|▌         | 56/1000 [00:12<03:16,  4.81it/s]
#
#
# Episode 56, Wins: 8, Replay Loss: 9.39178:   6%|▌         | 56/1000 [00:12<03:27,  4.54it/s]
#
#
# Episode 56, Wins: 8, Replay Loss: 9.39178:   6%|▌         | 57/1000 [00:12<03:10,  4.95it/s]
#
#
# Episode 57, Wins: 8, Replay Loss: 9.89861:   6%|▌         | 57/1000 [00:12<03:27,  4.55it/s]
#
#
# Episode 57, Wins: 8, Replay Loss: 9.89861:   6%|▌         | 58/1000 [00:12<03:10,  4.94it/s]
#
#
# Episode 58, Wins: 8, Replay Loss: 9.29077:   6%|▌         | 58/1000 [00:12<03:26,  4.57it/s]
#
#
# Episode 58, Wins: 8, Replay Loss: 9.29077:   6%|▌         | 59/1000 [00:12<03:02,  5.14it/s]
#
#
# Episode 59, Wins: 9, Replay Loss: 9.73314:   6%|▌         | 59/1000 [00:12<03:25,  4.57it/s]
#
#
# Episode 59, Wins: 9, Replay Loss: 9.73314:   6%|▌         | 60/1000 [00:12<03:05,  5.08it/s]
#
#
# Episode 60, Wins: 9, Replay Loss: 9.59728:   6%|▌         | 60/1000 [00:13<03:25,  4.58it/s]
#
#
# Episode 60, Wins: 9, Replay Loss: 9.59728:   6%|▌         | 61/1000 [00:13<03:05,  5.07it/s]
#
#
# Episode 61, Wins: 10, Replay Loss: 11.1455:   6%|▌         | 61/1000 [00:13<03:24,  4.60it/s]
#
#
# Episode 61, Wins: 10, Replay Loss: 11.1455:   6%|▌         | 62/1000 [00:13<02:55,  5.34it/s]
#
#
# Episode 62, Wins: 10, Replay Loss: 9.45927:   6%|▌         | 62/1000 [00:13<03:23,  4.61it/s]
#
#
# Episode 62, Wins: 10, Replay Loss: 9.45927:   6%|▋         | 63/1000 [00:13<02:58,  5.25it/s]

# %%
val_game = NeuralNaviGame(8, 8, model = model0)

# %%
val_game.setup()

# %%
animate_game(val_game, n = 10)
# Out:
# None

# %%
val_game.shift_goal()

# %%
f, axarr = pl.subplots(2, 2)
# f.title("RL Loss, 100 eps w/ 50 steps, Look: 20")
x = np.linspace(0, len(log[0]), len(log[0]))
axarr[0, 0].plot(x, np.log(log[0]))
axarr[0, 0].set_title('Log Total Loss')
axarr[0, 1].plot(x, log[0])
axarr[0, 1].set_title('Total Loss')
axarr[1, 0].plot(x, np.log(log[1]))
axarr[1, 0].set_title('Log Replay Loss')
axarr[1, 1].plot(x, log[1])
axarr[1, 1].set_title('Replay Loss')
f.subplots_adjust(hspace=0.5)

pl.plot()
pl.savefig("notes/rl_curve_x.png")
pl.show()

# %%
len(log[0]) == len(log[1])
# Out:
# True
