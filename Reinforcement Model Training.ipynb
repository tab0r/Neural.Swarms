# %%
from reinforcement_training import *
from notebook_game_helper import *

# %%
model0, log = main(training_episodes = 1000, steps = 20)
# Out:
# Episode 999 loss: 36.0573: 100%|██████████| 1000/1000 [14:33<00:00,  1.12it/s]

# %%
val_game = NeuralNaviGame(10, 10, model = model0, moving_target = True)

# %%
val_game.setup()

# %%
animate_game(val_game, n = 5)
# Out:
# None

# %%
val_game.shift_goal()

# %%
pl.plot(log)
pl.title("RL Loss, 1000 eps w/ 20 steps, Look: 50")
pl.savefig("notes/rl_curve_7.png")
pl.show()
